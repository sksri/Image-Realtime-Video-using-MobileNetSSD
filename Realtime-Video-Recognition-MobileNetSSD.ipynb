# %%
# Import libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Streaming webcam videos
webcam_video_stream = cv2.VideoCapture(0)

while True:
    ret,current_frame = webcam_video_stream.read()
    img_to_detect = current_frame
    # get height and width of image
    img_height = img_to_detect.shape[0]
    img_width = img_to_detect.shape[1]
    # resize to mtach input size
    resized_img_to_detect = cv2.resize(img_to_detect,(300,300))
    # convert to blob to pass into model
    # recommended scale factor is 0.007843 and width, height of blob is 300,300 and mean of 255 is 127.5
    img_blob = cv2.dnn.blobFromImage(resized_img_to_detect,0.007843,(300,300),127.5)
    # Set of 21 class labels in alphabetical order (background + rest of 20 classes)
    class_labels = ['background','aeroplane','bicycle','bird','boat','bottle','bus','car','cat','chair','cow','dining table','dog','horse','motorbike','person','sheep','sofa','train','tv/monitor']
    # Loading pre-trained model from prototext and caffemodel files 
    mobilenetssd = cv2.dnn.readNetFromCaffe('datasets/mobilenetssd.prototext','datasets/mobilenetssd.caffemodel')
    # Input preprocessed blob into model and pass through the model
    mobilenetssd.setInput(img_blob)
    # obtain the detection predictions by the model using forward() method
    obj_detections = mobilenetssd.forward()
    # Loop over the detections
    no_of_detections = obj_detections.shape[2]

    for index in np.arange(0, no_of_detections):
        prediction_confidence = obj_detections[0,0,index,2]
        # take only predictions with confidence more than 20%
        if prediction_confidence > 0.1:
            # get the prediction label
            predicted_class_index = int(obj_detections[0,0,index,1])
            predicted_class_label = class_labels[predicted_class_index]
            # obtain the bounding box co-ordinates for the actual image from resized image size
            bounding_box = obj_detections[0,0,index,3:7] * np.array([img_width, img_height, img_width, img_height])
            (start_x_pt, start_y_pt, end_x_pt, end_y_pt) = bounding_box.astype("int")

            # Print the prediction in console
            predicted_class_label = "{}: {:2f}%".format(class_labels[predicted_class_index],prediction_confidence*100)
            print("predicted object {}: {}".format(index+1,predicted_class_label))

            # Draw rectangle and text in the image
            cv2.rectangle(img_to_detect, (start_x_pt,start_y_pt), (end_x_pt,end_y_pt), (0,0,255),2)
            cv2.putText(img_to_detect, predicted_class_label, (start_x_pt,start_y_pt-5), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0,255,0),1)
        
    cv2.imshow("Detection Output", img_to_detect)

    # terminate while loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


# releasing the stream and camera
webcam_video_stream.release()

# close all opencv windows
cv2.destroyAllWindows()
# Out:
# predicted object 1: person: 83.644950%
# predicted object 1: person: 99.739790%
# predicted object 1: person: 99.904913%
# predicted object 1: person: 99.193704%
# predicted object 1: person: 99.560648%
# predicted object 1: person: 99.731356%
# predicted object 1: person: 99.880409%
# predicted object 1: person: 99.882251%
# predicted object 1: person: 99.745542%
# predicted object 1: person: 99.900240%
# predicted object 1: person: 98.300028%
# predicted object 1: person: 99.599302%
# predicted object 1: person: 99.712569%
# predicted object 1: person: 99.641716%
# predicted object 1: person: 95.849156%
# predicted object 1: person: 99.747223%
# predicted object 1: person: 99.925572%
# predicted object 1: person: 99.858117%
# predicted object 1: person: 99.892020%
# predicted object 1: person: 99.914289%
# predicted object 1: person: 99.901736%
# predicted object 1: person: 99.927181%
# predicted object 1: person: 99.934977%
# predicted object 1: person: 99.897671%
# predicted object 1: person: 99.916291%
# predicted object 1: person: 99.905211%
# predicted object 1: person: 99.876297%
# predicted object 1: person: 99.662602%
# predicted object 1: person: 99.536115%
# predicted object 1: person: 99.753261%
# predicted object 1: person: 99.707866%
# predicted object 1: person: 99.830818%
# predicted object 1: person: 99.794430%
# predicted object 1: person: 99.676931%
# predicted object 1: person: 99.457031%
# predicted object 1: person: 99.706501%
# predicted object 1: person: 99.725372%
# predicted object 1: person: 99.750024%
# predicted object 1: person: 99.774039%
# predicted object 1: person: 99.729067%
# predicted object 1: person: 99.735272%
# predicted object 1: person: 99.784970%
# predicted object 1: person: 99.792898%
# predicted object 1: person: 99.743491%
# predicted object 1: person: 99.712712%
# predicted object 1: person: 99.718922%
# predicted object 1: person: 99.673045%
# predicted object 1: person: 99.861908%
# predicted object 1: person: 99.836272%
# predicted object 1: person: 99.845755%
# predicted object 1: person: 99.835229%
# predicted object 1: person: 99.823689%
# predicted object 1: person: 99.857259%
# predicted object 1: person: 99.819452%
# predicted object 1: person: 99.802291%
# predicted object 1: person: 99.803585%
# predicted object 1: person: 99.815410%
# predicted object 1: person: 99.814510%
# predicted object 1: person: 99.833846%
# predicted object 1: person: 99.809450%
# predicted object 1: person: 99.838054%
# predicted object 1: person: 99.751568%
# predicted object 1: person: 99.754971%
# predicted object 1: person: 99.850273%
# predicted object 1: person: 99.743432%
# predicted object 1: person: 99.765104%
# predicted object 1: person: 99.757355%
# predicted object 1: person: 99.897480%
# predicted object 1: person: 99.912637%
# predicted object 1: person: 98.941004%
# predicted object 1: person: 99.895966%
# predicted object 1: person: 99.634933%
# predicted object 1: person: 95.596462%
# predicted object 1: dog: 88.456446%
# predicted object 2: bicycle: 71.464616%
# predicted object 3: person: 55.351120%
# predicted object 1: person: 69.556189%
# predicted object 2: cat: 56.249297%
# predicted object 1: bicycle: 53.513962%
# predicted object 2: cat: 47.411394%
# predicted object 1: cat: 70.401794%
# predicted object 2: person: 25.235507%
# predicted object 1: cat: 53.572106%
# predicted object 2: dog: 45.651722%
# predicted object 3: person: 34.740984%
# predicted object 1: cat: 64.266819%
# predicted object 2: person: 47.300029%
# predicted object 1: person: 72.431338%
# predicted object 2: cat: 69.155383%
# predicted object 1: cat: 85.864633%
# predicted object 2: person: 60.234302%
# predicted object 1: cat: 67.597514%
# predicted object 2: person: 55.866861%
# predicted object 3: bicycle: 31.329453%
# predicted object 1: person: 77.484578%
# predicted object 2: cat: 40.852550%
# predicted object 1: dog: 65.111154%
# predicted object 2: cat: 43.259326%
# predicted object 3: person: 40.816227%
# predicted object 4: bicycle: 29.676253%
# predicted object 1: cat: 47.852033%
# predicted object 2: person: 37.746614%
# predicted object 3: dog: 33.568671%
# predicted object 1: person: 87.202549%
# predicted object 2: cat: 82.162839%
# predicted object 1: person: 86.360639%
# predicted object 2: cat: 67.887574%
# predicted object 3: bicycle: 29.022604%
# predicted object 1: person: 76.521593%
# predicted object 2: cat: 62.222195%
# predicted object 3: bicycle: 47.157660%
# predicted object 1: person: 73.184109%
# predicted object 2: cat: 62.909997%
# predicted object 1: cat: 86.046219%
# predicted object 2: person: 73.642296%
# predicted object 1: person: 73.081726%
# predicted object 2: cat: 63.710552%
# predicted object 3: dog: 25.692546%
# predicted object 1: person: 64.903271%
# predicted object 2: dog: 55.752820%
# predicted object 3: cat: 39.499018%
# predicted object 1: person: 57.945544%
# predicted object 2: cat: 48.054919%
# predicted object 3: dog: 38.244641%
# predicted object 1: person: 56.217748%
# predicted object 2: dog: 55.643064%
# predicted object 3: cat: 34.458950%
# predicted object 1: dog: 80.097628%
# predicted object 2: person: 43.455744%
# predicted object 1: dog: 49.154231%
# predicted object 2: person: 34.558848%
# predicted object 1: cat: 56.726950%
# predicted object 2: person: 51.744229%
# predicted object 1: dog: 76.309991%
# predicted object 2: bicycle: 57.995623%
# predicted object 3: person: 51.000905%
# predicted object 1: person: 72.906524%
# predicted object 2: cat: 43.605259%
# predicted object 3: bicycle: 38.529414%
# predicted object 1: dog: 41.465786%
# predicted object 1: dog: 47.436520%
# predicted object 2: person: 44.360155%
# predicted object 3: cat: 32.683316%
# predicted object 1: person: 79.823041%
# predicted object 2: cat: 35.133666%
# predicted object 1: dog: 54.833496%
# predicted object 2: cat: 38.031825%
# predicted object 3: person: 36.310571%
# predicted object 4: bicycle: 32.573920%
# predicted object 1: cat: 62.321657%
# predicted object 2: person: 61.090010%
# predicted object 3: dog: 32.666105%
# predicted object 4: bicycle: 29.530233%
# predicted object 1: person: 58.788621%
# predicted object 2: dog: 51.358384%
# predicted object 3: bicycle: 27.292922%
# predicted object 1: bicycle: 61.495805%
# predicted object 2: dog: 60.333252%
# predicted object 3: person: 53.849548%
# predicted object 1: dog: 57.265985%
# predicted object 2: person: 28.754282%
# predicted object 3: cat: 28.715831%
# predicted object 1: cat: 63.702118%
# predicted object 2: person: 47.741237%
# predicted object 3: bicycle: 45.225275%
# predicted object 4: dog: 28.645095%
# predicted object 1: person: 75.744104%
# predicted object 2: cat: 63.620341%
# predicted object 3: bicycle: 34.922114%
# predicted object 4: dog: 33.865660%
# predicted object 1: cat: 76.050562%
# predicted object 2: person: 65.541184%
# predicted object 3: bicycle: 56.855869%
# predicted object 1: cat: 70.297599%
# predicted object 2: bicycle: 60.479838%
# predicted object 3: person: 59.781861%
# predicted object 4: dog: 34.014460%
# predicted object 1: person: 75.352800%
# predicted object 2: bicycle: 65.416342%
# predicted object 3: dog: 59.787500%
# predicted object 4: cat: 29.216224%
# predicted object 1: person: 61.503285%
# predicted object 2: bicycle: 49.804005%
# predicted object 3: dog: 38.381115%
# predicted object 4: cat: 31.473574%
# predicted object 1: person: 59.908044%
# predicted object 2: bicycle: 52.599263%
# predicted object 3: dog: 36.104000%
# predicted object 1: person: 43.801489%
# predicted object 2: dog: 36.742830%
# predicted object 3: cat: 36.189923%
# predicted object 4: bicycle: 34.759760%
# predicted object 1: person: 52.538419%
# predicted object 2: dog: 44.958588%
# predicted object 3: bicycle: 30.578375%
# predicted object 1: person: 41.938412%
# predicted object 2: bicycle: 32.955223%
# predicted object 3: cat: 30.925667%
# predicted object 1: person: 42.306060%
# predicted object 2: bicycle: 38.468045%
# predicted object 3: dog: 37.281084%
# predicted object 4: cat: 28.539851%
# predicted object 1: bicycle: 66.215605%
# predicted object 2: person: 43.512323%
# predicted object 3: dog: 41.869336%
# predicted object 4: cat: 35.264266%
# predicted object 1: dog: 51.598054%
# predicted object 2: person: 42.671767%
# predicted object 3: bicycle: 29.496711%
# predicted object 4: cat: 26.532647%
# predicted object 1: dog: 42.432955%
# predicted object 2: person: 35.003477%
# predicted object 3: bicycle: 32.859126%
# predicted object 4: cat: 32.456380%
# predicted object 1: cat: 45.372626%
# predicted object 2: bicycle: 41.534901%
# predicted object 3: person: 36.211750%
# predicted object 4: dog: 32.887465%
# predicted object 1: bicycle: 59.256268%
# predicted object 2: person: 51.492506%
# predicted object 3: cat: 39.124233%
# predicted object 4: dog: 38.185373%
# predicted object 1: dog: 54.358822%
# predicted object 2: person: 45.074478%
# predicted object 3: cat: 25.898519%
# predicted object 1: person: 60.135609%
# predicted object 2: cat: 49.022326%
# predicted object 3: dog: 40.907970%
# predicted object 1: dog: 50.295705%
# predicted object 2: person: 37.520835%
# predicted object 3: cat: 36.037669%
# predicted object 1: person: 57.826102%
# predicted object 2: dog: 37.371513%
# predicted object 3: cat: 32.417849%
# predicted object 1: person: 52.043027%
# predicted object 2: dog: 27.971345%
# predicted object 3: cat: 27.179059%
# predicted object 1: person: 73.185414%
# predicted object 2: dog: 72.317588%
# predicted object 3: cat: 25.871363%
# predicted object 1: person: 69.219148%
# predicted object 2: dog: 64.274836%
# predicted object 1: dog: 44.657654%
# predicted object 2: person: 42.427090%
# predicted object 1: person: 86.011511%
# predicted object 2: cat: 46.170914%
# predicted object 3: dog: 36.031869%
# predicted object 1: dog: 77.094090%
# predicted object 2: person: 77.065223%
# predicted object 1: dog: 74.387985%
# predicted object 2: person: 65.339392%
# predicted object 1: cat: 69.329089%
# predicted object 2: person: 68.000221%
# predicted object 3: dog: 48.618782%
# predicted object 1: person: 84.149975%
# predicted object 2: dog: 66.331685%
# predicted object 3: cat: 33.610249%
# predicted object 1: person: 71.686327%
# predicted object 2: cat: 50.022721%
# predicted object 3: dog: 48.861656%
# predicted object 1: cat: 54.553175%
# predicted object 2: dog: 50.684744%
# predicted object 3: person: 45.409822%
# predicted object 1: dog: 66.411704%
# predicted object 2: cat: 39.548764%
# predicted object 3: person: 29.256663%
# predicted object 1: dog: 57.839024%
# predicted object 2: cat: 50.886279%
# predicted object 3: person: 47.345296%
# predicted object 1: dog: 67.949069%
# predicted object 2: person: 44.759056%
# predicted object 3: cat: 26.496905%
# predicted object 1: dog: 85.634154%
# predicted object 2: person: 71.941721%
# predicted object 3: cat: 25.503924%
# predicted object 1: dog: 86.844307%
# predicted object 2: person: 68.218112%
# predicted object 1: dog: 86.400890%
# predicted object 2: person: 52.514565%
# predicted object 3: cat: 29.414457%
# predicted object 1: dog: 85.164976%
# predicted object 2: person: 48.153758%
# predicted object 1: dog: 79.099059%
# predicted object 2: person: 54.733384%
# predicted object 1: dog: 62.978089%
# predicted object 2: person: 56.994736%
# predicted object 3: cat: 38.203624%
# predicted object 1: dog: 84.957403%
# predicted object 2: person: 45.206097%
# predicted object 1: dog: 59.082437%
# predicted object 2: cat: 25.038102%
# predicted object 1: dog: 72.599673%
# predicted object 2: cat: 34.166259%
# predicted object 1: dog: 81.474763%
# predicted object 2: person: 70.138890%
# predicted object 1: person: 87.469357%
# predicted object 2: cat: 57.244796%
# predicted object 3: dog: 35.560551%
# predicted object 1: person: 87.416983%
# predicted object 2: cat: 79.935515%
# predicted object 3: dog: 31.834421%
# predicted object 1: person: 78.108859%
# predicted object 2: cat: 47.010511%
# predicted object 1: cat: 79.892868%
# predicted object 2: dog: 28.678599%
# predicted object 1: person: 96.054286%
# predicted object 1: person: 91.420966%
# predicted object 1: person: 88.966346%
# predicted object 2: dog: 39.588594%
# predicted object 1: person: 99.847680%
# predicted object 1: person: 99.766433%
# predicted object 1: person: 99.678063%
# predicted object 1: person: 99.730444%
# predicted object 1: person: 99.111712%
# predicted object 1: person: 99.445301%
# predicted object 1: person: 98.773861%
# predicted object 1: person: 99.461836%
# predicted object 1: person: 99.421316%
# predicted object 1: person: 99.623883%
# predicted object 1: person: 99.567348%
# predicted object 1: person: 99.549484%
# predicted object 1: person: 99.359339%
# predicted object 1: person: 99.443662%
# predicted object 1: person: 99.402195%
# predicted object 1: person: 99.457872%
# predicted object 1: person: 99.286908%
# predicted object 1: person: 99.038470%
# predicted object 1: person: 99.158126%
# predicted object 1: person: 99.395353%
# predicted object 1: person: 99.451882%
# predicted object 1: person: 99.397403%
# predicted object 1: person: 99.490070%
# predicted object 1: person: 99.376571%
# predicted object 1: person: 99.347490%
# predicted object 1: person: 99.377453%
# predicted object 1: person: 98.919672%
# predicted object 2: person: 50.042641%
# predicted object 1: person: 99.498785%
# predicted object 2: person: 44.089776%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-a92c74bc142a> in <module>
#      30             # get the prediction label
#      31             predicted_class_index = int(obj_detections[0,0,index,1])
# ---> 32             predicted_class_label = class_labels[predicted_class_index]
#      33             # obtain the bounding box co-ordinates for the actual image from resized image size
#      34             bounding_box = obj_detections[0,0,index,3:7] * np.array([img_width, img_height, img_width, img_height])
#
# IndexError: list index out of range
